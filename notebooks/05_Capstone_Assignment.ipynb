# %% [markdown]
# <a href="https://colab.research.google.com/github/Suroj22/python-basics/blob/main/notebooks/05_Capstone_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Full Capstone Assignment — Python for Earth System & Remote Sensing**
#
# This Capstone Assignment integrates all major skills from Notebooks **01 → 04**:
#
# - Python fundamentals
# - Lists, loops, conditions
# - Functions & plotting
# - NumPy
# - xarray
# - NetCDF
# - Scientific interpretation
#
# **This assignment is designed to be completed over multiple days** and tests understanding, reasoning, coding clarity, and scientific interpretation.

# %% [markdown]
# ---
# # **Section 0 — Setup (Required)**
#
# Run the cell below to import the scientific Python libraries you need for the assignment.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
# %matplotlib inline

# %% [markdown]
# ---
# # **Section 1 — Python Fundamentals (Notebook 01)**
#
# ### **Q1.1 — Arithmetic & Variables**
# Create:
# - `a = 12`
# - `b = 4.7`
# - `c = -3`
#
# Compute and print:
# 1. `a + b`
# 2. `a * c`
# 3. `(a + b) / c`
#
# Use f-strings to print meaningful messages.

# %%
# Q1.1
a=12
b=4.7
c=-3
print(a+b)
print(a*c)
print((a+b)/c)
# Out:
# 16.7
# -36
# -5.566666666666666

# %% [markdown]
# ### **Q1.2 — Basic Statistics**
# Given:
# ```python
# sst = [27.9, 28.0, 28.4, 28.6, 28.8, 29.1, 28.7, 28.3, 27.8]
# ```
#
# Compute:
# - Mean
# - Median
# - Minimum
# - Maximum
# - Standard deviation
#
# Print with clear labels.

# %%
# Q1.2
import numpy as np
sst = [27.9,28.0,28.4,28.6,28.8,29.1,28.7,28.3,27.8]
print("Sum : ",sum(sst))
print("Mean :",np.mean(sst))
print("Media :",np.median(sst))
print("Minimum :",np.min(sst))
print("Maximum :",np.max(sst))
print("standard deviation :",np.std(sst))
# Out:
# Sum :  255.6
# Mean : 28.400000000000002
# Media : 28.4
# Minimum : 27.8
# Maximum : 29.1
# standard deviation : 0.416333199893227

# %% [markdown]
# ---
# # **Section 2 — Lists, Loops, and Conditions (Notebook 02)**
#
# ### **Q2.1 — Day-wise SST Printing**
# Using the `sst` list from Q1.2, print:
#
# ```
# Day 1: value
# Day 2: value
# ...
# ```

# %%
# Q2.1
sst = [27.9,28.0,28.4,28.6,28.8,29.1,28.7,28.3,27.8]
for i in range(len(sst)):
  temp=sst[i]
  print(f"Day {i+1} : {temp}")
# Out:
# Day 1 : 27.9
# Day 2 : 28.0
# Day 3 : 28.4
# Day 4 : 28.6
# Day 5 : 28.8
# Day 6 : 29.1
# Day 7 : 28.7
# Day 8 : 28.3
# Day 9 : 27.8

# %% [markdown]
# ### **Q2.2 — Classification**
# Classify each SST into:
# - **HOT** (> 29)
# - **WARM** (28–29)
# - **NORMAL** (< 28)
#
# Print classification for each day.
# At the end, print counts for each category.

# %%
# Q2.2
sst = [27.9,28.0,28.4,28.6,28.8,29.1,28.7,28.3,27.8]
hot_sst=[]
warm_sst=[]
normal_sst=[]

for i in range(len(sst)):
  temp=sst[i]
  if temp>29:
    hot_sst.append(temp)
  if temp>=28:
    warm_sst.append(temp)
  if temp<28:
    normal_sst.append(temp)

print("Hot : ",hot_sst)
print("Warm : ",warm_sst)
print("Normal : ",normal_sst)
# Out:
# Hot :  [29.1]
# Warm :  [28.0, 28.4, 28.6, 28.8, 29.1, 28.7, 28.3]
# Normal :  [27.9, 27.8]

# %% [markdown]
# ### **Q2.3 — Rolling 3-day Mean**
# Compute a 3-day rolling mean using loops (without NumPy).
# Example output:
# ```
# Mean Day1-3: ...
# Mean Day2-4: ...
# ...
# ```

# %%
# Q2.3
sst = [27.9,28.0,28.4,28.6,28.8,29.1,28.7,28.3,27.8]
for i in range(len(sst)-2):
  temp=(sst[i]+sst[i+1]+sst[i+2])/3
  print(f"Mean Day {i+1}-{i+3} : {temp}")
# Out:
# Mean Day 1-3 : 28.099999999999998
# Mean Day 2-4 : 28.333333333333332
# Mean Day 3-5 : 28.599999999999998
# Mean Day 4-6 : 28.833333333333332
# Mean Day 5-7 : 28.86666666666667
# Mean Day 6-8 : 28.7
# Mean Day 7-9 : 28.266666666666666

# %% [markdown]
# ---
# # **Section 3 — Functions, Arrays, and Plotting (Notebook 03)**
#
# ### **Q3.1 — Function: Celsius → Kelvin**
# Define:
# ```python
# def c_to_k(T_c):
#     ...
# ```
# Test on 5 sample values.

# %%
# Q3.1
def c_to_k(T_c):
  T_k=T_c+273.15
  return T_k

print(c_to_k(20))
print(c_to_k(25))
print(c_to_k(30))
print(c_to_k(35))
print(c_to_k(40))
# Out:
# 293.15
# 298.15
# 303.15
# 308.15
# 313.15

# %% [markdown]
# ### **Q3.2 — Function: Anomaly Computation**
# Define:
# ```python
# def compute_anomaly(arr):
#     ...
# ```
# Return array − mean.
# Test using `sst`.

# %%
# Q3.2
import numpy as np

sst = [27.9,28.0,28.4,28.6,28.8,29.1,28.7,28.3,27.8]

def compute_anomaly(arr):
  mean=np.mean(arr)
  anomaly=arr-mean
  return anomaly

print(compute_anomaly(sst))
# Out:
# [-5.00000000e-01 -4.00000000e-01 -3.55271368e-15  2.00000000e-01
#   4.00000000e-01  7.00000000e-01  3.00000000e-01 -1.00000000e-01
#  -6.00000000e-01]

# %% [markdown]
# ### **Q3.3 — Convert to NumPy + Plot**
#
# 1. Convert `sst` to a NumPy array
# 2. Compute anomalies
# 3. Create a line plot of SST
# 4. Create a second plot of anomalies
# 5. Include:
#    - Titles
#    - Axis labels
#    - Grid
#    - A horizontal zero line for anomalies

# %%
# Q3.3
import matplotlib.pyplot as plt
import numpy as np

sst=np.array([27.9,28.0,28.4,28.6,28.8,29.1,28.7,28.3,27.8])

def compute_anomaly(arr):
  mean=np.mean(arr)
  anomaly = arr - mean
  return anomaly

anomaly=compute_anomaly(sst)

days = np.arange(0,9)
plt.figure()
plt.plot(days,anomaly, marker= '*')
plt.title("Anomaly")
plt.xlabel("Days")
plt.ylabel("Anomaly")
plt.grid(True)
plt.axhline(y=0, color='r', linestyle='-')
plt.show()

plt.figure()
plt.plot(days, sst, marker= '*')
plt.title('day')
plt.xlabel('Days')
plt.ylabel('SST')
plt.grid(True)
plt.axhline(y=0, color='r', linestyle='-')
plt.show()

# %% [markdown]
# ---
# # **Section 4 — NetCDF + xarray: Remote Sensing Dataset (Notebook 04)**
#
# A small SST NetCDF file will be downloaded automatically.

# %%
# Auto-download NetCDF file
import requests, os
import xarray as xr

url = "https://raw.githubusercontent.com/EarthSystem-Science-Lab/python-basics/main/data/data_sst.nc"
local = "data_sst.nc"

if not os.path.exists(local):
    r = requests.get(url)
    open(local,"wb").write(r.content)

ds = xr.open_dataset(local)
ds
# Out:
# <xarray.Dataset> Size: 7kB
# Dimensions:  (time: 7, lat: 11, lon: 11)
# Coordinates:
#   * time     (time) datetime64[ns] 56B 2020-01-01 2020-01-02 ... 2020-01-07
#   * lat      (lat) float64 88B 10.0 11.0 12.0 13.0 14.0 ... 17.0 18.0 19.0 20.0
#   * lon      (lon) float64 88B 70.0 71.0 72.0 73.0 74.0 ... 77.0 78.0 79.0 80.0
# Data variables:
#     sst      (time, lat, lon) float64 7kB ...
# Attributes:
#     title:    Sample synthetic SST dataset for teaching
#     source:   Generated in Python for teaching by Arjun's EarthSystem-Science...
#     history:  Created as a small example NetCDF file for Notebook 4

# %% [markdown]
# ### **Q4.1 — Dataset Exploration**
# Print:
# - Dimensions
# - Coordinates
# - Variables
# - Global attributes

# %%
# Q4.1
var = ds.variables
print("Dimensions : ",ds.dims)
print("Coordinates : ",ds.coords)
print("Variables : ",ds.data_vars)
print("Global attributes : ",ds.attrs)
# Out:
# Dimensions :  FrozenMappingWarningOnValuesAccess({'time': 7, 'lat': 11, 'lon': 11})
# Coordinates :  Coordinates:
#   * time     (time) datetime64[ns] 56B 2020-01-01 2020-01-02 ... 2020-01-07
#   * lat      (lat) float64 88B 10.0 11.0 12.0 13.0 14.0 ... 17.0 18.0 19.0 20.0
#   * lon      (lon) float64 88B 70.0 71.0 72.0 73.0 74.0 ... 77.0 78.0 79.0 80.0
# Variables :  Data variables:
#     sst      (time, lat, lon) float64 7kB ...
# Global attributes :  {'title': 'Sample synthetic SST dataset for teaching', 'source': "Generated in Python for teaching by Arjun's EarthSystem-Science-Lab", 'history': 'Created as a small example NetCDF file for Notebook 4'}

# %% [markdown]
# ### **Q4.2 — Statistics on `sst`**
# Compute and print:
# - Global mean
# - Min
# - Max

# %%
# Q4.2
print(f"Global Mean: {ds.sst.mean}")
print(f"Min: {ds.sst.min}")
print(f"Max: {ds.sst.max}")
# Out:
# Global Mean: <bound method DataArrayAggregations.mean of <xarray.DataArray 'sst' (time: 7, lat: 11, lon: 11)> Size: 7kB
# [847 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 56B 2020-01-01 2020-01-02 ... 2020-01-07
#   * lat      (lat) float64 88B 10.0 11.0 12.0 13.0 14.0 ... 17.0 18.0 19.0 20.0
#   * lon      (lon) float64 88B 70.0 71.0 72.0 73.0 74.0 ... 77.0 78.0 79.0 80.0
# Attributes:
#     long_name:  Sea Surface Temperature
#     units:      degree_Celsius>
# Min: <bound method DataArrayAggregations.min of <xarray.DataArray 'sst' (time: 7, lat: 11, lon: 11)> Size: 7kB
# [847 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 56B 2020-01-01 2020-01-02 ... 2020-01-07
#   * lat      (lat) float64 88B 10.0 11.0 12.0 13.0 14.0 ... 17.0 18.0 19.0 20.0
#   * lon      (lon) float64 88B 70.0 71.0 72.0 73.0 74.0 ... 77.0 78.0 79.0 80.0
# Attributes:
#     long_name:  Sea Surface Temperature
#     units:      degree_Celsius>
# Max: <bound method DataArrayAggregations.max of <xarray.DataArray 'sst' (time: 7, lat: 11, lon: 11)> Size: 7kB
# [847 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 56B 2020-01-01 2020-01-02 ... 2020-01-07
#   * lat      (lat) float64 88B 10.0 11.0 12.0 13.0 14.0 ... 17.0 18.0 19.0 20.0
#   * lon      (lon) float64 88B 70.0 71.0 72.0 73.0 74.0 ... 77.0 78.0 79.0 80.0
# Attributes:
#     long_name:  Sea Surface Temperature
#     units:      degree_Celsius>

# %% [markdown]
# ### **Q4.3 — Time-Mean Map**
# 1. Compute `sst_mean_time = ds.sst.mean(dim='time')`
# 2. Plot a colour map (lat vs lon)
# 3. Add labels, title, and colorbar

# %%
# Q4.3
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import requests, os

url = "https://raw.githubusercontent.com/EarthSystem-Science-Lab/python-basics/main/data/data_sst.nc"
local = "data_sst.nc"

if not os.path.exists(local):
    r = requests.get(url)
    open(local,"wb").write(r.content)

ds = xr.open_dataset(local)

sst_mean_time = ds.sst.mean(dim='time')
plt.figure(figsize=(10, 8))
p= sst_mean_time.plot(cmap='jet') #store the plot object
plt.title("Time-mean SST")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.colorbar(p, label="SST(°C)")
plt.show()

# %% [markdown]
# ### **Q4.4 — Time Series at a Point**
# Choose a latitude & longitude inside file domain.
# Extract nearest time series and plot it.
#
# Add axis labels and title.

# %%
# Q4.4
import xarray as xr
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/EarthSystem-Science-Lab/python-basics/main/data/data_sst.nc"
local = "data_sst.nc"

ds = xr.open_dataset("data_sst.nc")

lat_pt = 13
lon_pt = 74

ts = ds.sst.sel(lat=lat_pt, lon=lon_pt, method='nearest')

plt.figure(figsize=(10, 6))
ts.plot()
plt.title(f"Time Series at ({lat_pt}, {lon_pt})")
plt.xlabel("Time")
plt.ylabel("SST")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# # **Section 5 — Capstone Scientific Interpretation**
#
# Write **10–12 sentences** answering:
#
# 1. What spatial patterns do you observe in your time-mean SST map?
# 2. Does the time series at your chosen point indicate warming/cooling or variability?
# 3. What physical processes (mixing, stratification, insolation, currents, monsoon) could explain the patterns?
# 4. How do your anomaly results relate to the NetCDF dataset behavior?
# 5. How would these methods apply to real satellite (Sentinel-3/OLCI) or Argo data?
#
# Write your answer below.

# %% [markdown]
# 1. In the plot of Time mean SST 70°-80°E Longitude and 10°-20°N Latitude the scale is showing 26.6 to 27 °C (Low SST), 27.0 to 27.4 °C(Medium SST), 27.4 to 27.8 °C (High SST). The map shows the increase of temperature with the increase of Latitude.
# 2. Time series SST at my chosen point indicate increase of wartming.
# 3. Physical Process like stratification in warm regions maintain high sst and while mixing in colder or stromy regions cools the surface.
# 4. SST anomailes are computed relative to climatological mean derived from the NetCDF datasets. Reflect how the data sets captures variability over time rather than absolute  temperature.
# 5. Satellite data and Argo data combined used, satellites capture spatial structure, Argo explains Vertical processes behindobserved sst changes
